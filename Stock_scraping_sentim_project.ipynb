# %%
import requests
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer 
import matplotlib.pyplot as plt
import json
from datetime import date, timedelta
import datetime as dt
import yfinance as yf

# %%
# def getStockDataframe(symbols, in_days):
    
#     df_stocktwits = pd.DataFrame(columns = ['symbol', 'text', 'sentiment', 'time'])
#     start_date = dt.datetime.now() - dt.timedelta(days=in_days)
#     start_date = start_date.date()  
#     for symbol in symbols:
#         ChangeSymbol = False
#         maxCursor = ''        
#         while ChangeSymbol == False:
# #             print('maxCursor = ' + maxCursor)

#             # 1. fetch stock data
#             r1 = requests.get('https://api.stocktwits.com/api/2/streams/symbol/' + symbol + '.json?filter=top&limit=20&max=' + maxCursor)
#             data = r1.json()
#             if r1.status_code != 200:
#                 print('make more than 200 requests an hour')
#                 print(data)
#                 return df_stocktwits

#             # 2. update maxCursor
#             maxCursor = str(data['cursor']['max'])

#             # 3. parse data and put into dataframe
#             rows = []
#             for msg in data['messages']:
#                 text = msg['body']
#                 time_str = msg['created_at'][:10]
#                 sentiments = msg['entities']['sentiment']
#                 symbol = data['symbol']['symbol']
#                 if sentiments != 'null':
#                     sentiment = str(sentiments)[11:-2]
#                 else :
#                     sentiment = ''
#                 date_time_obj = dt.datetime.strptime(time_str, '%Y-%m-%d')
#                 date_time_obj = date_time_obj.date()

#                 # check messages are enough 
#                 if date_time_obj <= start_date:
#     #                 print('hasAllMessage = ' + time_str)
#                     ChangeSymbol = True
#                     break

#                 rows.append([symbol, text, sentiment, date_time_obj])

#             df_stocktwits = df_stocktwits.append(pd.DataFrame(rows, columns = ['symbol', 'text', 'sentiment', 'time']), ignore_index=True)
#             df_stocktwits = df_stocktwits.sort_values(by=['symbol'], ignore_index = True)
                            
#     news_tables = {}
#     parse_data_news = []
#     for symbol in symbols:
#         url = 'https://finviz.com/quote.ashx?t=' + symbol + '&ty=c&ta=1&p=d'
#         r2 = requests.get(url, headers={'user-agent': 'my-app'})
#         soup1 = BeautifulSoup(r2.text, 'html')
#         all_news=soup1.find(id="news-table")
#         news_tables[symbol] = all_news

#         for symbol, news_table in  news_tables.items():
#             for titles in news_table.findAll('tr'):
#                 datetime = titles.td.text
#                 title = titles.a.text
#                 channel = titles.span.text
#                 news_url = titles.a['href']
#                 if len(datetime.split(" ")) == 1:
#                     time = datetime[0:7]
#                 else:
#                     date = datetime[0:9]
#                     time = datetime[11:17]

#                 date = pd.to_datetime(date)
#                 parse_data_news.append([symbol, date, time, title, channel, news_url])
#                 df_finviz = pd.DataFrame(parse_data_news, columns =['symbol','date', 'time', 'title', 'channel', 'news_url'])
#         df_finviz = df_finviz.append(pd.DataFrame(df_finviz, columns =['symbol','date', 'time', 'title', 'channel', 'news_url']), ignore_index=True)
#         df_finviz = df_finviz.sort_values(by=['symbol'], ignore_index = True)

        
#     rating_tables = {}
#     parse_data_rating = []       
#     for symbol in symbols:
#         url = 'https://finviz.com/quote.ashx?t=' + symbol + '&ty=c&ta=1&p=d'
#         r2 = requests.get(url, headers={'user-agent': 'my-app'})
#         soup2 = BeautifulSoup(r2.text, 'html')
#         all_rating=soup2.findAll(class_="fullview-ratings-inner")
#         rating_tables[symbol] = all_rating

#         for symbol, ratings in rating_tables.items():
#             for rating in ratings:
#                 date= rating.text.split('\n')[1][:9]
#                 date = dt.datetime.strptime(date, '%b-%d-%y')
#                 date = date.date()
#                 action= rating.text.split('\n')[1][9:]
#                 organization= rating.text.split('\n')[2]
#                 suggestion= rating.text.split('\n')[3]
#                 target_price= rating.text.split('\n')[4]
                
#                 parse_data_rating.append([symbol, date, action, organization, suggestion, target_price])
#         df_rating = pd.DataFrame(parse_data_rating, columns = ['symbol', 'date', 'action', 'organization', 'suggestion', 'target_price'])
#         df_rating = df_rating.sort_values(by=['symbol'], ignore_index = True)
        
#     return df_finviz, df_stocktwits, df_rating


# df_finviz, df_stocktwits, df_rating= getStockDataframe(['ZM', 'SQ', 'HPQ'], 2)
# Out:
# make more than 200 requests an hour
# {'response': {'status': 429}, 'errors': [{'message': 'Rate limit exceeded. Client may not make more than 200 requests an hour.'}]}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-d6c6f45f2e20> in <module>
#     100
#     101
# --> 102 df_finviz, df_stocktwits, df_rating= getStockDataframe(['ZM', 'SQ', 'HPQ'], 2)
#     103
#
# ValueError: too many values to unpack (expected 3)

# %%
def getStockDataframe(symbols, in_days):
    
    df_stocktwits = pd.DataFrame(columns = ['symbol', 'text', 'sentiment', 'time'])
    start_date = dt.datetime.now() - dt.timedelta(days=in_days)
    start_date = start_date.date()  
    for symbol in symbols:
        ChangeSymbol = False
        maxCursor = ''        
        while ChangeSymbol == False:
#             print('maxCursor = ' + maxCursor)

            # 1. fetch stock data
            r1 = requests.get('https://api.stocktwits.com/api/2/streams/symbol/' + symbol + '.json?filter=top&limit=20&max=' + maxCursor)
            data = r1.json()
            if r1.status_code != 200:
                print('make more than 200 requests an hour')
                print(data)
                return df_stocktwits

            # 2. update maxCursor
            maxCursor = str(data['cursor']['max'])

            # 3. parse data and put into dataframe
            rows = []
            for msg in data['messages']:
                text = msg['body']
                time_str = msg['created_at'][:10]
                sentiments = msg['entities']['sentiment']
                symbol = data['symbol']['symbol']
                if sentiments != 'null':
                    sentiment = str(sentiments)[11:-2]
                else :
                    sentiment = ''
                date_time_obj = dt.datetime.strptime(time_str, '%Y-%m-%d')
                date_time_obj = date_time_obj.date()

                # check messages are enough 
                if date_time_obj <= start_date:
    #                 print('hasAllMessage = ' + time_str)
                    ChangeSymbol = True
                    break

                rows.append([symbol, text, sentiment, date_time_obj])

            df_stocktwits = df_stocktwits.append(pd.DataFrame(rows, columns = ['symbol', 'text', 'sentiment', 'time']), ignore_index=True)
            df_stocktwits = df_stocktwits.sort_values(by=['symbol'], ignore_index = True)
                            
    news_tables = {}
    parse_data_news = []
    for symbol in symbols:
        url = 'https://finviz.com/quote.ashx?t=' + symbol + '&ty=c&ta=1&p=d'
        r2 = requests.get(url, headers={'user-agent': 'my-app'})
        soup1 = BeautifulSoup(r2.text, 'html')
        all_news=soup1.find(id="news-table")
        news_tables[symbol] = all_news

        for symbol, news_table in  news_tables.items():
            for titles in news_table.findAll('tr'):
                datetime = titles.td.text
                title = titles.a.text
                channel = titles.span.text
                news_url = titles.a['href']
                if len(datetime.split(" ")) == 1:
                    time = datetime[0:7]
                else:
                    date = datetime[0:9]
                    time = datetime[11:17]

                date = pd.to_datetime(date)
                parse_data_news.append([symbol, date, time, title, channel, news_url])
                df_finviz = pd.DataFrame(parse_data_news, columns =['symbol','date', 'time', 'title', 'channel', 'news_url'])
        df_finviz = df_finviz.append(pd.DataFrame(df_finviz, columns =['symbol','date', 'time', 'title', 'channel', 'news_url']), ignore_index=True)
        df_finviz = df_finviz.sort_values(by=['symbol'], ignore_index = True)

        
    rating_tables = {}
    parse_data_rating = []       
    for symbol in symbols:
        url = 'https://finviz.com/quote.ashx?t=' + symbol + '&ty=c&ta=1&p=d'
        r2 = requests.get(url, headers={'user-agent': 'my-app'})
        soup2 = BeautifulSoup(r2.text, 'html')
        all_rating=soup2.findAll(class_="fullview-ratings-inner")
        rating_tables[symbol] = all_rating

        for symbol, ratings in rating_tables.items():
            for rating in ratings:
                date= rating.text.split('\n')[1][:9]
                date = dt.datetime.strptime(date, '%b-%d-%y')
                date = date.date()
                action= rating.text.split('\n')[1][9:]
                organization= rating.text.split('\n')[2]
                suggestion= rating.text.split('\n')[3]
                target_price= rating.text.split('\n')[4]
                
                parse_data_rating.append([symbol, date, action, organization, suggestion, target_price])
        df_rating = pd.DataFrame(parse_data_rating, columns = ['symbol', 'date', 'action', 'organization', 'suggestion', 'target_price'])
        df_rating = df_rating.sort_values(by=['symbol'], ignore_index = True)
    
    
    df_hist_data= pd.DataFrame([],columns = ['symbol', 'Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock', 'Splits'])
    for symbol in symbols:
        all_info = yf.Ticker(symbol)
        hist_data = all_info.history(period = 'max')
        hist_data['symbol']= symbol
        hist_data.reset_index(inplace=True)
        hist_data = hist_data.rename(columns = {'index': 'Date'})
        df_hist_data = df_hist_data.append(hist_data)
        
    return df_finviz, df_stocktwits, df_rating, df_hist_data


df_finviz, df_stocktwits, df_rating, df_hist_data= getStockDataframe(['ZM', 'SQ'], 3)

# %%
df_finviz
# Out:
#     symbol       date     time  \
# 0       SQ 2021-03-05  12:31PM
# 1       SQ 2021-03-11  07:15AM
# 2       SQ 2021-03-11  09:56AM
# 3       SQ 2021-03-11  09:57AM
# 4       SQ 2021-03-11  12:10PM
# ..     ...        ...      ...
# 595     ZM 2021-03-23   2:32PM
# 596     ZM 2021-03-24  01:29PM
# 597     ZM 2021-03-24   3:49PM
# 598     ZM 2021-03-20  11:56AM
# 599     ZM 2021-04-02   0:37PM
#
#                                                  title          channel  \
# 0    Positive Outlook Makes Foley Trasimene Acquisi...    InvestorPlace
# 1        Should You Invest in Crypto Stocks Right Now?      Motley Fool
# 2    3 Stocks With Notable Insider Transactions In ...         Benzinga
# 3    Square Makes a Deal With Jay-Z, and Okta Buys ...      Motley Fool
# 4    What is an NFT? A Beeple NFT just sold on Chri...      MarketWatch
# ..                                                 ...              ...
# 595                   Why Zoom Video Stock Just Popped      Motley Fool
# 596  Why Zoom, Peloton, and Fastly Stocks Were Slam...      Motley Fool
# 597           Top Communications Stocks for April 2021     Investopedia
# 598  Cathie Woods Thoughts on the Future, ARKs Port...   Insider Monkey
# 599             Why Zoom Video Stock Fell 14% in March      Motley Fool
#
#                                               news_url
# 0    https://finance.yahoo.com/news/positive-outloo...
# 1    https://www.fool.com/investing/2021/03/11/shou...
# 2    https://finance.yahoo.com/news/3-stocks-notabl...
# 3    https://www.fool.com/investing/2021/03/11/squa...
# 4    https://www.marketwatch.com/story/what-is-an-n...
# ..                                                 ...
# 595  https://www.fool.com/investing/2021/03/23/why-...
# 596  https://www.fool.com/investing/2021/03/24/why-...
# 597  https://www.investopedia.com/top-communication...
# 598  https://finance.yahoo.com/news/cathie-wood-tho...
# 599  https://www.fool.com/investing/2021/04/02/why-...
#
# [600 rows x 6 columns]

# %%
df_stocktwits
# Out:
#     symbol                                               text sentiment  \
# 0       SQ  $SQ [15s. delayed] filed SEC form 4: Director ...
# 1       SQ  https://www.youtube.com/watch?v=fVg6XYYcybc \n...   Bullish
# 2       SQ  $HMBL HUMBL ETX gains. Not even a week. $PYPL ...
# 3       SQ                                  $SQ $240 tomorrow   Bullish
# 4       SQ  On modern digital platforms, the network of pe...
# ..     ...                                                ...       ...
# 313     ZM  $ZM pump, pump, pump, shart the bed.  Last hur...   Bearish
# 314     ZM  $APHA &amp; $TLRY this year like $ZM &amp; $MR...   Bullish
# 315     ZM  $ZM The 2 year treasuries are up 16%. If that ...   Bearish
# 316     ZM  What are today the #BestStocks for medium-term...
# 317     ZM  Worth The Wait: Fast Out Of The Gate Three Day...
#
#            time
# 0    2021-04-05
# 1    2021-04-04
# 2    2021-04-05
# 3    2021-04-05
# 4    2021-04-05
# ..          ...
# 313  2021-04-03
# 314  2021-04-05
# 315  2021-04-03
# 316  2021-04-05
# 317  2021-04-05
#
# [318 rows x 4 columns]

# %%
df_rating
# Out:
#    symbol        date      action               organization  \
# 0      SQ  2020-07-09   Downgrade                      Cowen
# 1      SQ  2021-03-31     Upgrade             Keefe Bruyette
# 2      SQ  2021-03-12   Initiated                    Redburn
# 3      SQ  2021-02-25     Upgrade                 Guggenheim
# 4      SQ  2021-02-24   Downgrade                Wells Fargo
# 5      SQ  2021-01-27     Resumed                  Bernstein
# 6      SQ  2020-12-23   Initiated            Robert W. Baird
# 7      SQ  2020-12-22  Reiterated              BTIG Research
# 8      SQ  2020-12-07   Initiated  Seaport Global Securities
# 9      SQ  2021-02-17  Reiterated              Deutsche Bank
# 10     SQ  2020-11-10     Upgrade              BTIG Research
# 11     SQ  2020-12-03     Upgrade               Evercore ISI
# 12     SQ  2020-08-05  Reiterated           RBC Capital Mkts
# 13     SQ  2020-08-06     Upgrade              Compass Point
# 14     SQ  2020-08-27   Initiated                     Mizuho
# 15     SQ  2020-07-14   Initiated                    Goldman
# 16     SQ  2020-09-24     Upgrade                Oppenheimer
# 17     SQ  2020-09-29     Upgrade             Wolfe Research
# 18     SQ  2020-11-06     Upgrade                  Citigroup
# 19     SQ  2020-09-22   Initiated               Loop Capital
# 20     ZM  2020-09-01     Upgrade              BTIG Research
# 21     ZM  2020-09-01  Reiterated                  JP Morgan
# 22     ZM  2020-09-01  Reiterated             Morgan Stanley
# 23     ZM  2020-09-01  Reiterated                    Needham
# 24     ZM  2020-09-01  Reiterated              Piper Sandler
# 25     ZM  2020-09-01  Reiterated           RBC Capital Mkts
# 26     ZM  2020-09-01  Reiterated            Robert W. Baird
# 27     ZM  2020-09-01  Reiterated                 Rosenblatt
# 28     ZM  2020-09-01  Reiterated                Wells Fargo
# 29     ZM  2020-09-01  Reiterated                DA Davidson
# 30     ZM  2021-03-31   Initiated           Daiwa Securities
# 31     ZM  2020-10-15  Reiterated                  Bernstein
# 32     ZM  2021-03-26   Initiated              Deutsche Bank
# 33     ZM  2021-03-16     Resumed              Credit Suisse
# 34     ZM  2021-03-02     Upgrade              Piper Sandler
# 35     ZM  2020-12-09   Downgrade                  JP Morgan
# 36     ZM  2020-10-15  Reiterated           RBC Capital Mkts
# 37     ZM  2020-10-15  Reiterated                    Needham
# 38     ZM  2020-10-15  Reiterated                  Bernstein
# 39     ZM  2020-10-09   Initiated                     Mizuho
# 40     ZM  2020-09-01     Upgrade                    Goldman
# 41     ZM  2020-09-01     Upgrade              BTIG Research
# 42     ZM  2020-09-01  Reiterated                Wells Fargo
# 43     ZM  2020-09-01  Reiterated                 Rosenblatt
# 44     ZM  2020-10-09   Initiated                     Mizuho
# 45     ZM  2020-09-01  Reiterated            Robert W. Baird
# 46     ZM  2020-09-01  Reiterated              Piper Sandler
# 47     ZM  2020-09-01  Reiterated                    Needham
# 48     ZM  2020-09-01  Reiterated             Morgan Stanley
# 49     ZM  2020-09-01  Reiterated                  JP Morgan
# 50     ZM  2020-09-01  Reiterated                DA Davidson
# 51     ZM  2021-03-31   Initiated           Daiwa Securities
# 52     ZM  2021-03-26   Initiated              Deutsche Bank
# 53     ZM  2021-03-16     Resumed              Credit Suisse
# 54     ZM  2021-03-02     Upgrade              Piper Sandler
# 55     ZM  2020-12-09   Downgrade                  JP Morgan
# 56     ZM  2020-10-15  Reiterated           RBC Capital Mkts
# 57     ZM  2020-10-15  Reiterated                    Needham
# 58     ZM  2020-09-01  Reiterated           RBC Capital Mkts
# 59     ZM  2020-09-01     Upgrade                    Goldman
#
#                      suggestion target_price
# 0   Outperform → Market Perform         $119
# 1      Mkt Perform → Outperform         $250
# 2                          Sell
# 3                 Neutral → Buy         $288
# 4     Overweight → Equal Weight         $255
# 5                    Outperform         $266
# 6                       Neutral         $245
# 7                           Buy  $220 → $295
# 8                           Buy         $250
# 9                           Buy  $255 → $330
# 10                Neutral → Buy         $220
# 11         In-line → Outperform         $300
# 12                   Outperform  $119 → $200
# 13               Sell → Neutral         $140
# 14                          Buy         $225
# 15                      Neutral         $133
# 16         Perform → Outperform         $185
# 17    Peer Perform → Outperform         $195
# 18                Neutral → Buy  $185 → $215
# 19                          Buy         $169
# 20                Neutral → Buy         $500
# 21                   Overweight  $220 → $425
# 22                 Equal-Weight  $240 → $350
# 23                          Buy  $230 → $440
# 24                      Neutral  $211 → $411
# 25                   Outperform  $300 → $450
# 26                   Outperform  $300 → $465
# 27                          Buy  $260 → $350
# 28                 Equal Weight  $195 → $375
# 29                          Buy  $240 → $460
# 30                         Sell         $250
# 31                   Outperform  $228 → $611
# 32                         Hold         $360
# 33                 Underperform         $375
# 34         Neutral → Overweight  $501 → $541
# 35         Overweight → Neutral         $450
# 36                   Outperform  $450 → $600
# 37                          Buy  $440 → $540
# 38                   Outperform  $228 → $611
# 39                          Buy         $550
# 40               Sell → Neutral  $187 → $402
# 41                Neutral → Buy         $500
# 42                 Equal Weight  $195 → $375
# 43                          Buy  $260 → $350
# 44                          Buy         $550
# 45                   Outperform  $300 → $465
# 46                      Neutral  $211 → $411
# 47                          Buy  $230 → $440
# 48                 Equal-Weight  $240 → $350
# 49                   Overweight  $220 → $425
# 50                          Buy  $240 → $460
# 51                         Sell         $250
# 52                         Hold         $360
# 53                 Underperform         $375
# 54         Neutral → Overweight  $501 → $541
# 55         Overweight → Neutral         $450
# 56                   Outperform  $450 → $600
# 57                          Buy  $440 → $540
# 58                   Outperform  $300 → $450
# 59               Sell → Neutral  $187 → $402

# %%
df_hist_data
# Out:
#      symbol       Date        Open        High         Low       Close  \
# 0        ZM 2019-04-18   65.000000   66.000000   60.320999   62.000000
# 1        ZM 2019-04-22   61.000000   68.900002   59.939999   65.699997
# 2        ZM 2019-04-23   66.870003   74.168999   65.550003   69.000000
# 3        ZM 2019-04-24   71.400002   71.500000   63.160000   63.200001
# 4        ZM 2019-04-25   64.739998   66.849998   62.599998   65.000000
# ...     ...        ...         ...         ...         ...         ...
# 1346     SQ 2021-03-29  212.000000  214.389999  202.929993  207.179993
# 1347     SQ 2021-03-30  204.490005  214.300003  202.830002  212.830002
# 1348     SQ 2021-03-31  218.410004  232.759995  218.410004  227.050003
# 1349     SQ 2021-04-01  231.259995  236.460007  227.570007  229.509995
# 1350     SQ 2021-04-05  231.619995  233.320007  224.100006  229.949997
#
#         Volume Dividends Stock Splits  Stock Splits
# 0     25764700         0   NaN    NaN           0.0
# 1      9949700         0   NaN    NaN           0.0
# 2      6786500         0   NaN    NaN           0.0
# 3      4973500         0   NaN    NaN           0.0
# 4      3863300         0   NaN    NaN           0.0
# ...        ...       ...   ...    ...           ...
# 1346   9695800         0   NaN    NaN           0.0
# 1347   9735700         0   NaN    NaN           0.0
# 1348  14453700         0   NaN    NaN           0.0
# 1349   9260800         0   NaN    NaN           0.0
# 1350   7488501         0   NaN    NaN           0.0
#
# [1845 rows x 11 columns]
